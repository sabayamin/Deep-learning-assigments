# %% [markdown]
# <a href="https://colab.research.google.com/github/sabayamin/Deep-learning-assigments/blob/main/Ionosphere_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment: Ionosphere Data Problem
#
# ### Dataset Description:
#
# This radar data was collected by a system in Goose Bay, Labrador. This system consists of a phased array of 16 high-frequency antennas with a total transmitted power on the order of 6.4 kilowatts. See the paper for more details. The targets were free electrons in the ionosphere. "Good" radar returns are those showing evidence of some type of structure in the ionosphere. "Bad" returns are those that do not; their signals pass through the ionosphere.
#
# Received signals were processed using an autocorrelation function whose arguments are the time of a pulse and the pulse number. There were 17 pulse numbers for the Goose Bay system. Instances in this databse are described by 2 attributes per pulse number, corresponding to the complex values returned by the function resulting from the complex electromagnetic signal.
#
# ### Attribute Information:
#
# - All 34 are continuous
# - The 35th attribute is either "good" or "bad" according to the definition summarized above. This is a binary classification task.
#
#  <br><br>
#
# <table border="1"  cellpadding="6">
# 	<tbody>
#         <tr>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Data Set Characteristics:&nbsp;&nbsp;</b></p></td>
# 		<td><p class="normal">Multivariate</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Number of Instances:</b></p></td>
# 		<td><p class="normal">351</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Area:</b></p></td>
# 		<td><p class="normal">Physical</p></td>
#         </tr>
#      </tbody>
#     </table>
# <table border="1" cellpadding="6">
#     <tbody>
#         <tr>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Attribute Characteristics:</b></p></td>
#             <td><p class="normal">Integer,Real</p></td>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Number of Attributes:</b></p></td>
#             <td><p class="normal">34</p></td>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Date Donated</b></p></td>
#             <td><p class="normal">N/A</p></td>
#         </tr>
#      </tbody>
#     </table>
# <table border="1" cellpadding="6">
#     <tbody>
#     <tr>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Associated Tasks:</b></p></td>
# 		<td><p class="normal">Classification</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Missing Values?</b></p></td>
# 		<td><p class="normal">N/A</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Number of Web Hits:</b></p></td>
# 		<td><p class="normal">N/A</p></td>
# 	</tr>
#     </tbody>
#     </table>

# %% [markdown]
# ### WORKFLOW :
# - Load Data
# - Check Missing Values ( If Exist ; Fill each record with mean of its feature ) or any usless column.
# - Shuffle the data if needed.
# - Standardized the Input Variables. **Hint**: Centeralized the data
# - Split into 60 and 40 ratio.
# - Encode labels.
# - Model : 1 hidden layers including 16 unit.
# - Compilation Step (Note : Its a Binary problem , select loss , metrics according to it)
# - Train the Model with Epochs (100).
# - If the model gets overfit tune your model by changing the units , No. of layers , epochs , add dropout layer or add Regularizer according to the need .
# - Prediction should be > **92%**
# - Evaluation Step
# - Prediction

# %% [markdown]
# # Load Data:
# [Click Here to Download DataSet](https://github.com/ramsha275/ML_Datasets/blob/main/ionosphere_data.csv)

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
df = pd.read_csv("/content/gdrive/MyDrive/ionosphere_data.csv")
df.head()
# Out:
#    feature1  feature2  feature3  ...  feature33  feature34  label
# 0         1         0   0.99539  ...    0.18641   -0.45300      g
# 1         1         0   1.00000  ...   -0.13738   -0.02447      b
# 2         1         0   1.00000  ...    0.56045   -0.38238      g
# 3         1         0   1.00000  ...   -0.32382    1.00000      b
# 4         1         0   1.00000  ...   -0.04608   -0.65697      g
#
# [5 rows x 35 columns]

# %%
df1 =df['label']
df1.value_counts()
# Out:
# g    225
# b    126
# Name: label, dtype: int64

# %%
df1 =df['label']
df1.value_counts()
# Out:
# g    225
# b    126
# Name: label, dtype: int64

# %%
df.sample(3)
# Out:
#      feature1  feature2  feature3  ...  feature33  feature34  label
# 255         1         0   0.83427  ...   -0.03983    0.79444      g
# 203         1         0   1.00000  ...    0.86364    0.04545      g
# 38          1         0   0.91241  ...    0.65258    0.11447      g
#
# [3 rows x 35 columns]

# %%
df.drop_duplicates()
# Out:
#      feature1  feature2  feature3  ...  feature33  feature34  label
# 0           1         0   0.99539  ...    0.18641   -0.45300      g
# 1           1         0   1.00000  ...   -0.13738   -0.02447      b
# 2           1         0   1.00000  ...    0.56045   -0.38238      g
# 3           1         0   1.00000  ...   -0.32382    1.00000      b
# 4           1         0   1.00000  ...   -0.04608   -0.65697      g
# ..        ...       ...       ...  ...        ...        ...    ...
# 346         1         0   0.83508  ...    0.90546   -0.04307      g
# 347         1         0   0.95113  ...    0.91483    0.04712      g
# 348         1         0   0.94701  ...    0.92697   -0.00577      g
# 349         1         0   0.90608  ...    0.87403   -0.16243      g
# 350         1         0   0.84710  ...    0.85764   -0.06151      g
#
# [350 rows x 35 columns]

# %%
df.describe()
# Out:
#          feature1  feature2    feature3  ...   feature32   feature33   feature34
# count  351.000000     351.0  351.000000  ...  351.000000  351.000000  351.000000
# mean     0.891738       0.0    0.641342  ...   -0.003794    0.349364    0.014480
# std      0.311155       0.0    0.497708  ...    0.513574    0.522663    0.468337
# min      0.000000       0.0   -1.000000  ...   -1.000000   -1.000000   -1.000000
# 25%      1.000000       0.0    0.472135  ...   -0.242595    0.000000   -0.165350
# 50%      1.000000       0.0    0.871110  ...    0.000000    0.409560    0.000000
# 75%      1.000000       0.0    1.000000  ...    0.200120    0.813765    0.171660
# max      1.000000       0.0    1.000000  ...    1.000000    1.000000    1.000000
#
# [8 rows x 34 columns]

# %%
data=df.iloc[:,:-1]
label=df.iloc[:,-1]

# %%
label = df["label"].map({'g':1,'b':0})

# %%
X_train=data.sample(frac=0.6,random_state=1)
X_test=data.sample(frac=0.4,random_state=1)
y_train=label.sample(frac=0.6,random_state=1)
y_test=label.sample(frac=0.4,random_state=1)

# %%
X_train=np.asarray(X_train).astype("float32")
X_test=np.asarray(X_test).astype("float32")

# %%
from keras import models, layers , optimizers ,regularizers,losses
network=models.Sequential()
network.add(layers.Dense(16,activation="relu",input_shape=(X_train.shape[1],)))
#network.add(layers.Dense(8,kernel_regularizer=regularizers.l2(0.0001),activation="relu"))
network.add(layers.Dense(1,activation="sigmoid"))
network.compile(optimizer="rmsprop",loss="binary_crossentropy",metrics=["accuracy"])

# %%
network.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                560
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 577
# Trainable params: 577
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = network.fit(X_train,y_train,epochs=50,batch_size=1,verbose=1)
# Out:
# Epoch 1/50
# 211/211 [==============================] - 1s 1ms/step - loss: 0.5567 - accuracy: 0.7558
# Epoch 2/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.5429 - accuracy: 0.7688
# Epoch 3/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.4146 - accuracy: 0.8567
# Epoch 4/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.3620 - accuracy: 0.8639
# Epoch 5/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.3719 - accuracy: 0.9179
# Epoch 6/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.2710 - accuracy: 0.9123
# Epoch 7/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.2552 - accuracy: 0.9146
# Epoch 8/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.2681 - accuracy: 0.9250
# Epoch 9/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.2464 - accuracy: 0.9332
# Epoch 10/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.2250 - accuracy: 0.9279
# Epoch 11/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.2539 - accuracy: 0.8996
# Epoch 12/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1817 - accuracy: 0.9121
# Epoch 13/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1680 - accuracy: 0.9370
# Epoch 14/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1834 - accuracy: 0.9182
# Epoch 15/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1879 - accuracy: 0.9238
# Epoch 16/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1443 - accuracy: 0.9454
# Epoch 17/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.2521 - accuracy: 0.9369
# Epoch 18/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1060 - accuracy: 0.9637
# Epoch 19/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1842 - accuracy: 0.9378
# Epoch 20/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1576 - accuracy: 0.9459
# Epoch 21/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1441 - accuracy: 0.9481
# Epoch 22/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1715 - accuracy: 0.9428
# Epoch 23/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.2049 - accuracy: 0.9468
# Epoch 24/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0829 - accuracy: 0.9860
# Epoch 25/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1662 - accuracy: 0.9257
# Epoch 26/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.2290 - accuracy: 0.9529
# Epoch 27/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1334 - accuracy: 0.9622
# Epoch 28/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1509 - accuracy: 0.9636
# Epoch 29/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1486 - accuracy: 0.9564
# Epoch 30/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1201 - accuracy: 0.9681
# Epoch 31/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0904 - accuracy: 0.9780
# Epoch 32/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1408 - accuracy: 0.9546
# Epoch 33/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1352 - accuracy: 0.9620
# Epoch 34/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1525 - accuracy: 0.9462
# Epoch 35/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0901 - accuracy: 0.9841
# Epoch 36/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0935 - accuracy: 0.9643
# Epoch 37/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0964 - accuracy: 0.9691
# Epoch 38/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0812 - accuracy: 0.9720
# Epoch 39/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1034 - accuracy: 0.9649
# Epoch 40/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0986 - accuracy: 0.9750
# Epoch 41/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0788 - accuracy: 0.9753
# Epoch 42/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1317 - accuracy: 0.9652
# Epoch 43/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1016 - accuracy: 0.9727
# Epoch 44/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0749 - accuracy: 0.9744
# Epoch 45/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1507 - accuracy: 0.9387
# Epoch 46/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0744 - accuracy: 0.9743
# Epoch 47/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0875 - accuracy: 0.9748
# Epoch 48/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0825 - accuracy: 0.9735
# Epoch 49/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.1054 - accuracy: 0.9585
# Epoch 50/50
# 211/211 [==============================] - 0s 1ms/step - loss: 0.0578 - accuracy: 0.9817

# %%
history_dict = history.history
history_dict.keys()
[u'accuracy', u'loss']
# Out:
# ['accuracy', 'loss']

# %%
loss_acc=pd.DataFrame(history.history)
loss_acc.tail().T
# Out:
#                 45        46        47        48        49
# loss      0.090360  0.091455  0.092034  0.077548  0.089394
# accuracy  0.971564  0.971564  0.971564  0.971564  0.971564

# %%
import matplotlib.pyplot as plt
history_dict = history.history
loss_values = history_dict['loss']
accuracy_values = history_dict['accuracy']
epochs = range(1, len(history_dict['accuracy']) + 1)
plt.plot(epochs, loss_values, 'g', label='loss')
plt.plot(epochs, accuracy_values, 'b', label='accuracy')
plt.title('Accuracy & Loss ')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# %%
network.evaluate(X_test,y_test)
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0693 - accuracy: 0.9786
# [0.06925346702337265, 0.9785714149475098]

# %%
pred=network.predict(X_test)
pred.flatten().astype("U8")
# Out:
# array(['0.002454', '0.999165', '1.977491', '0.998917', '0.960718',
#        '0.998941', '0.998923', '0.983802', '0.000565', '0.054918',
#        '0.997349', '0.998841', '0.004096', '0.995310', '4.535252',
#        '0.012782', '0.853816', '0.005675', '0.989851', '4.045925',
#        '0.772085', '0.972376', '0.998820', '0.903761', '1.850337',
#        '0.999225', '0.993482', '0.998059', '0.956801', '0.998046',
#        '0.004679', '0.998808', '0.000126', '0.029164', '0.997935',
#        '0.998505', '0.030084', '7.122538', '0.998403', '0.999437',
#        '0.973701', '0.994099', '0.991827', '0.998373', '0.998842',
#        '0.961567', '0.998110', '0.996425', '0.055407', '0.995264',
#        '0.956310', '0.999479', '0.111434', '0.002798', '0.999673',
#        '0.988543', '0.001390', '4.602662', '0.001003', '0.997633',
#        '0.994182', '0.000870', '0.998690', '0.000876', '4.927232',
#        '0.991647', '1.899283', '0.999434', '0.996116', '3.580201',
#        '0.996422', '0.024443', '0.000221', '0.998900', '0.008371',
#        '1.620321', '0.998296', '0.997037', '0.997181', '0.982584',
#        '0.963086', '0.999684', '0.993925', '0.999632', '0.998985',
#        '0.999337', '0.996792', '0.997299', '0.977247', '0.997236',
#        '0.983249', '9.358651', '0.000153', '0.972437', '0.998360',
#        '0.000570', '0.996958', '0.996018', '0.991684', '0.998159',
#        '0.996595', '6.281212', '0.976340', '0.999102', '0.998175',
#        '0.798048', '4.895858', '0.997947', '0.999599', '0.997664',
#        '0.999499', '0.996720', '0.943656', '0.996746', '0.999351',
#        '0.987035', '0.000118', '0.997197', '4.504885', '0.989159',
#        '0.998725', '0.928191', '3.362601', '0.986177', '0.992596',
#        '0.021562', '0.985836', '0.002238', '0.999076', '0.998775',
#        '0.997214', '0.999548', '0.849717', '0.004371', '0.995159',
#        '0.002311', '0.970196', '2.121948', '0.998188', '6.850714'],
#       dtype='<U8')
